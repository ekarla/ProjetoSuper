# %%
#extraindo uma parte do pdf cpm tabula-py

import tabula
# fazendo a leitura do pdf por inteiro

#dadosFvs = tabula.read_pdf('boletim-diario-de-casos-covid-19-10-06-2020.pdf',stream = True
#)

# %%
dadosFvs[0]
# Out:
#     Unnamed: 0   Unnamed: 1                                   Unnamed: 2  \
# 0          NaN          NaN                                          NaN
# 1          NaN   Municípios                                          NaN
# 2          NaN          NaN  (óbitos/100.000)Notificados Confirmados (5)
# 3          NaN          NaN                                          NaN
# 4          NaN          NaN                                          NaN
# ..         ...          ...                                          ...
# 73        59.0         Apuí                                       149 27
# 74         NaN          NaN                                          NaN
# 75        60.0   Envira (2)                                         11 0
# 76        61.0  Ipixuna (2)                                         18 0
# 77         NaN        TOTAL                               116.956 52.849
#
#                             Casos       Unnamed: 3    Unnamed: 4  Unnamed: 5  \
# 0                             NaN              NaN           NaN         NaN
# 1                             NaN              NaN  No de óbitos  Letalidade
# 2   Confirmados % de participação       Incidência           NaN         NaN
# 3     Clínico Epid. por Município  (casos/100.000)           NaN         NaN
# 4                             NaN              NaN           NaN         NaN
# ..                            ...              ...           ...         ...
# 73                        0 0,05%           122,88             0       0,00%
# 74                            NaN              NaN           NaN         NaN
# 75                        0 0,00%             0,00             0       0,00%
# 76                        0 0,00%             0,00             0       0,00%
# 77                       461 100%         1.275,13         2.363       4,47%
#
#      Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# 0   Mortalidade         NaN        NaN
# 1           NaN         NaN       REDE
# 2           NaN         NaN    PRIVADA
# 3           NaN         NaN        NaN
# 4           NaN         NaN    PÚBLICA
# ..          ...         ...        ...
# 73         0,00         NaN        NaN
# 74          NaN         NaN        NaN
# 75         0,00         NaN        NaN
# 76         0,00         NaN        NaN
# 77        57,01         NaN        NaN
#
#                      INTERNADOS CONFIRMADOS EM MANAUS Unnamed: 9  \
# 0                                                 NaN        NaN
# 1                   INTERNADOS LEITO CLÍNICO % EM UTI          %
# 2                                     84 31 36,90% 53     63,10%
# 3                                                 NaN        NaN
# 4                                   276 182 65,94% 94     34,06%
# ..                                                ...        ...
# 73                                                NaN        NaN
# 74  Monitoramento da realização de exames para ide...        NaN
# 75                                                NaN        NaN
# 76  http://www.fvs.am.gov.br/indicadorSalaSituacao...        NaN
# 77                                                NaN        NaN
#
#    CONSOLIDADO CASOS DE
# 0            INTERNAÇÃO
# 1                   NaN
# 2         LEITO CLÍNICO
# 3                   NaN
# 4                   NaN
# ..                  ...
# 73                  NaN
# 74                  NaN
# 75                  NaN
# 76                  NaN
# 77                  NaN
#
# [78 rows x 13 columns]

# %%
#Lendo somente a planilha de casos contidas no pdf 
dados = tabula.read_pdf('boletim-diario-de-casos-covid-19-10-06-2020.pdf', area=[90,10,600,555], pages ='1'
)

# %%
dados[0]
# Out:
#     Unnamed: 0  Unnamed: 1         Casos       Unnamed: 2  Unnamed: 3  \
# 0          NaN  Municípios           NaN              NaN         NaN
# 1          NaN         NaN   Notificados  Confirmados (5)         NaN
# 2          NaN         NaN           NaN              NaN         NaN
# 3          NaN      Manaus        58.978           22.159       143.0
# 4          NaN    INTERIOR        57.978           30.690       318.0
# ..         ...         ...           ...              ...         ...
# 62         NaN          58  Canutama (1)              124        36.0
# 63         NaN          59          Apuí              149        27.0
# 64         NaN          60    Envira (2)               11         0.0
# 65         NaN          61   Ipixuna (2)               18         0.0
# 66         NaN       TOTAL       116.956           52.849       461.0
#
#    Unnamed: 4 Unnamed: 5    Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN  No de óbitos  Letalidade        NaN        NaN
# 1         NaN        NaN           NaN         NaN        NaN        NaN
# 2         NaN        NaN           NaN         NaN        NaN        NaN
# 3      41,93%   1.015,18         1.534       6,92%      70,28        NaN
# 4      58,07%   1.564,35           829       2,70%      42,26        NaN
# ..        ...        ...           ...         ...        ...        ...
# 62          0      0,07%        230,34           0      0,00%       0,00
# 63          0      0,05%        122,88           0      0,00%       0,00
# 64          0      0,00%          0,00           0      0,00%       0,00
# 65          0      0,00%          0,00           0      0,00%       0,00
# 66       100%   1.275,13         2.363       4,47%      57,01        NaN
#
# [67 rows x 11 columns]

# %%
#começando a limpeza do dataframe
#excluindo a coluna com valores nulos Unnamed: 0
dados = dados[0].drop(['Unnamed: 0'], axis = 1)
dados
# Out:
#     Unnamed: 1         Casos       Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0   Municípios           NaN              NaN         NaN        NaN
# 1          NaN   Notificados  Confirmados (5)         NaN        NaN
# 2          NaN           NaN              NaN         NaN        NaN
# 3       Manaus        58.978           22.159       143.0     41,93%
# 4     INTERIOR        57.978           30.690       318.0     58,07%
# ..         ...           ...              ...         ...        ...
# 62          58  Canutama (1)              124        36.0          0
# 63          59          Apuí              149        27.0          0
# 64          60    Envira (2)               11         0.0          0
# 65          61   Ipixuna (2)               18         0.0          0
# 66       TOTAL       116.956           52.849       461.0       100%
#
#    Unnamed: 5    Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN  No de óbitos  Letalidade        NaN        NaN
# 1         NaN           NaN         NaN        NaN        NaN
# 2         NaN           NaN         NaN        NaN        NaN
# 3    1.015,18         1.534       6,92%      70,28        NaN
# 4    1.564,35           829       2,70%      42,26        NaN
# ..        ...           ...         ...        ...        ...
# 62      0,07%        230,34           0      0,00%       0,00
# 63      0,05%        122,88           0      0,00%       0,00
# 64      0,00%          0,00           0      0,00%       0,00
# 65      0,00%          0,00           0      0,00%       0,00
# 66   1.275,13         2.363       4,47%      57,01        NaN
#
# [67 rows x 10 columns]

# %%
dados.head()
# Out:
#    Unnamed: 1        Casos       Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Municípios          NaN              NaN         NaN        NaN        NaN
# 1         NaN  Notificados  Confirmados (5)         NaN        NaN        NaN
# 2         NaN          NaN              NaN         NaN        NaN        NaN
# 3      Manaus       58.978           22.159       143.0     41,93%   1.015,18
# 4    INTERIOR       57.978           30.690       318.0     58,07%   1.564,35
#
#      Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0  No de óbitos  Letalidade        NaN        NaN
# 1           NaN         NaN        NaN        NaN
# 2           NaN         NaN        NaN        NaN
# 3         1.534       6,92%      70,28        NaN
# 4           829       2,70%      42,26        NaN

# %%
temp = dados.loc[3:4]
temp
# Out:
#   Unnamed: 1   Casos Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3     Manaus  58.978     22.159       143.0     41,93%   1.015,18      1.534
# 4   INTERIOR  57.978     30.690       318.0     58,07%   1.564,35        829
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 3      6,92%      70,28        NaN
# 4      2,70%      42,26        NaN

# %%
temp = temp.rename(columns ={'Unnamed: 1':'Municipios','Casos':'Notificados','Unnamed: 2':'Confirmados',\
                            'Unnamed: 3':'Clinico Epidemiologico','Unnamed: 4':'% Participação por Municipio','Unnamed: 5':'Incidencia','Unnamed: 6':'Nº de Obitos',\
                            'Unnamed: 7':'Letalidade','Unnamed: 8':'Mortalidade'})
temp
# Out:
#   Municipios Notificados Confirmados  Clinico Epidemiologico  \
# 3     Manaus      58.978      22.159                   143.0
# 4   INTERIOR      57.978      30.690                   318.0
#
#   % Participação por Municipio Incidencia Nº de Obitos Letalidade Mortalidade  \
# 3                       41,93%   1.015,18        1.534      6,92%       70,28
# 4                       58,07%   1.564,35          829      2,70%       42,26
#
#   Unnamed: 9
# 3        NaN
# 4        NaN

# %%
temp = temp.drop('Unnamed: 9', axis=1)
temp
# Out:
#   Municipios Notificados Confirmados  Clinico Epidemiologico  \
# 3     Manaus      58.978      22.159                   143.0
# 4   INTERIOR      57.978      30.690                   318.0
#
#   % Participação por Municipio Incidencia Nº de Obitos Letalidade Mortalidade
# 3                       41,93%   1.015,18        1.534      6,92%       70,28
# 4                       58,07%   1.564,35          829      2,70%       42,26

# %%
dados = dados.drop([0,1,2,3,4])
dados
# Out:
#    Unnamed: 1                     Casos Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 5          01            Manacapuru (1)      6.558       2.728         12
# 6          02                      Tefé      2.774       2.391         65
# 7          03  São Gabriel da Cachoeira      2.666       2.352         43
# 8          04                     Coari      4.293       2.123          0
# 9          05                 Parintins      3.444       1.779          1
# ..        ...                       ...        ...         ...        ...
# 62         58              Canutama (1)        124      36.000          0
# 63         59                      Apuí        149      27.000          0
# 64         60                Envira (2)         11       0.000          0
# 65         61               Ipixuna (2)         18       0.000          0
# 66      TOTAL                   116.956     52.849     461.000       100%
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 5       5,16%   2.801,48        117      4,29%     120,15
# 6       4,52%   3.995,05         64      2,68%     106,94
# 7       4,45%   5.161,97         27      1,15%      59,26
# 8       4,02%   2.494,80         64      3,01%      75,21
# 9       3,37%   1.556,80         62      3,49%      54,26
# ..        ...        ...        ...        ...        ...
# 62      0,07%     230,34          0      0,00%       0,00
# 63      0,05%     122,88          0      0,00%       0,00
# 64      0,00%       0,00          0      0,00%       0,00
# 65      0,00%       0,00          0      0,00%       0,00
# 66   1.275,13      2.363      4,47%      57,01        NaN
#
# [62 rows x 10 columns]

# %%
dados = dados.drop('Unnamed: 1', axis = 1)
dados
# Out:
#                        Casos Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5             Manacapuru (1)      6.558       2.728         12      5,16%
# 6                       Tefé      2.774       2.391         65      4,52%
# 7   São Gabriel da Cachoeira      2.666       2.352         43      4,45%
# 8                      Coari      4.293       2.123          0      4,02%
# 9                  Parintins      3.444       1.779          1      3,37%
# ..                       ...        ...         ...        ...        ...
# 62              Canutama (1)        124      36.000          0      0,07%
# 63                      Apuí        149      27.000          0      0,05%
# 64                Envira (2)         11       0.000          0      0,00%
# 65               Ipixuna (2)         18       0.000          0      0,00%
# 66                   116.956     52.849     461.000       100%   1.275,13
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 5    2.801,48        117      4,29%     120,15
# 6    3.995,05         64      2,68%     106,94
# 7    5.161,97         27      1,15%      59,26
# 8    2.494,80         64      3,01%      75,21
# 9    1.556,80         62      3,49%      54,26
# ..        ...        ...        ...        ...
# 62     230,34          0      0,00%       0,00
# 63     122,88          0      0,00%       0,00
# 64       0,00          0      0,00%       0,00
# 65       0,00          0      0,00%       0,00
# 66      2.363      4,47%      57,01        NaN
#
# [62 rows x 9 columns]

# %%
# renomeando as colunas 
dados = dados.rename(columns ={"Casos":"Municipios",'Unnamed: 2':'Notificados','Unnamed: 3':'Confirmados','Unnamed: 4':'Clinico Epidemiologico','Unnamed: 5':'% Participação por Municipio','Unnamed: 6':'Incidencia','Unnamed: 7':'Nº de Obitos','Unnamed: 8':'Letalidade','Unnamed: 9':'Mortalidade'})

dados
# Out:
#                   Municipios Notificados  Confirmados Clinico Epidemiologico  \
# 5             Manacapuru (1)       6.558        2.728                     12
# 6                       Tefé       2.774        2.391                     65
# 7   São Gabriel da Cachoeira       2.666        2.352                     43
# 8                      Coari       4.293        2.123                      0
# 9                  Parintins       3.444        1.779                      1
# ..                       ...         ...          ...                    ...
# 62              Canutama (1)         124       36.000                      0
# 63                      Apuí         149       27.000                      0
# 64                Envira (2)          11        0.000                      0
# 65               Ipixuna (2)          18        0.000                      0
# 66                   116.956      52.849      461.000                   100%
#
#    % Participação por Municipio Incidencia Nº de Obitos Letalidade Mortalidade
# 5                         5,16%   2.801,48          117      4,29%      120,15
# 6                         4,52%   3.995,05           64      2,68%      106,94
# 7                         4,45%   5.161,97           27      1,15%       59,26
# 8                         4,02%   2.494,80           64      3,01%       75,21
# 9                         3,37%   1.556,80           62      3,49%       54,26
# ..                          ...        ...          ...        ...         ...
# 62                        0,07%     230,34            0      0,00%        0,00
# 63                        0,05%     122,88            0      0,00%        0,00
# 64                        0,00%       0,00            0      0,00%        0,00
# 65                        0,00%       0,00            0      0,00%        0,00
# 66                     1.275,13      2.363        4,47%      57,01         NaN
#
# [62 rows x 9 columns]

# %%
dados = dados.append(temp)
dados = dados.sort_index()
dados
# Out:
#                   Municipios Notificados Confirmados Clinico Epidemiologico  \
# 3                     Manaus      58.978      22.159                    143
# 4                   INTERIOR      57.978      30.690                    318
# 5             Manacapuru (1)       6.558       2.728                     12
# 6                       Tefé       2.774       2.391                     65
# 7   São Gabriel da Cachoeira       2.666       2.352                     43
# ..                       ...         ...         ...                    ...
# 62              Canutama (1)         124          36                      0
# 63                      Apuí         149          27                      0
# 64                Envira (2)          11           0                      0
# 65               Ipixuna (2)          18           0                      0
# 66                   116.956      52.849         461                   100%
#
#    % Participação por Municipio Incidencia Nº de Obitos Letalidade Mortalidade
# 3                        41,93%   1.015,18        1.534      6,92%       70,28
# 4                        58,07%   1.564,35          829      2,70%       42,26
# 5                         5,16%   2.801,48          117      4,29%      120,15
# 6                         4,52%   3.995,05           64      2,68%      106,94
# 7                         4,45%   5.161,97           27      1,15%       59,26
# ..                          ...        ...          ...        ...         ...
# 62                        0,07%     230,34            0      0,00%        0,00
# 63                        0,05%     122,88            0      0,00%        0,00
# 64                        0,00%       0,00            0      0,00%        0,00
# 65                        0,00%       0,00            0      0,00%        0,00
# 66                     1.275,13      2.363        4,47%      57,01         NaN
#
# [64 rows x 9 columns]

# %%
dados['DATA']= '10-06-2020'

# %%
import pandas as pd
dados['DATA']=pd.to_datetime(dados['DATA'])
dados
# Out:
#                   Municipios Notificados Confirmados Clinico Epidemiologico  \
# 3                     Manaus      58.978      22.159                    143
# 4                   INTERIOR      57.978      30.690                    318
# 5             Manacapuru (1)       6.558       2.728                     12
# 6                       Tefé       2.774       2.391                     65
# 7   São Gabriel da Cachoeira       2.666       2.352                     43
# ..                       ...         ...         ...                    ...
# 62              Canutama (1)         124          36                      0
# 63                      Apuí         149          27                      0
# 64                Envira (2)          11           0                      0
# 65               Ipixuna (2)          18           0                      0
# 66                   116.956      52.849         461                   100%
#
#    % Participação por Municipio Incidencia Nº de Obitos Letalidade  \
# 3                        41,93%   1.015,18        1.534      6,92%
# 4                        58,07%   1.564,35          829      2,70%
# 5                         5,16%   2.801,48          117      4,29%
# 6                         4,52%   3.995,05           64      2,68%
# 7                         4,45%   5.161,97           27      1,15%
# ..                          ...        ...          ...        ...
# 62                        0,07%     230,34            0      0,00%
# 63                        0,05%     122,88            0      0,00%
# 64                        0,00%       0,00            0      0,00%
# 65                        0,00%       0,00            0      0,00%
# 66                     1.275,13      2.363        4,47%      57,01
#
#    Mortalidade       DATA
# 3        70,28 2020-10-06
# 4        42,26 2020-10-06
# 5       120,15 2020-10-06
# 6       106,94 2020-10-06
# 7        59,26 2020-10-06
# ..         ...        ...
# 62        0,00 2020-10-06
# 63        0,00 2020-10-06
# 64        0,00 2020-10-06
# 65        0,00 2020-10-06
# 66         NaN 2020-10-06
#
# [64 rows x 10 columns]

# %%
#Lendo somente a planilha de casos contidas no pdf 
df = tabula.read_pdf('boletim-diario-de-casos-covid-19-10-06-2020.pdf', area=[80,490,380,1800], pages ='1'
)
df[0]
# Out:
#    Unnamed: 0                   INTERNADOS CONFIRMADOS EM MANAUS  Unnamed: 1  \
# 0         ade   INTERNAÇÃOREDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 1      0.000)                                                NaN         NaN
# 2         NaN                            PRIVADA 84 31 36,90% 53      63,10%
# 3         NaN                          PÚBLICA 276 182 65,94% 94      34,06%
# 4           8                           TOTAL 360 213 59,17% 147      40,83%
# 5           6                                                NaN         NaN
# 6           5                     INTERNADOS SUSPEITOS EM MANAUS         NaN
# 7           4             REDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 8           6                            PRIVADA 66 42 63,64% 24      36,36%
# 9           1                          PÚBLICA 300 214 71,33% 86      28,67%
# 10          6                           TOTAL 366 256 69,95% 110      30,05%
# 11          6                                                NaN         NaN
# 12          6                                             ÓBITOS         NaN
# 13          4                                        Confirmados         NaN
# 14          0        Notificados Últimas Confirmação Descartados  Aguardando
# 15        NaN                                    Acumulado TOTAL         NaN
# 16          7                           24 horas Diagnóstica (5)   Resultado
# 17          3                     2.920 2.363 4,47% 16 32 48 211          74
# 18          8                                                NaN         NaN
# 19          3  NOTA: Do total de 1615 casos cofirmados nas úl...         NaN
# 20          9  foram detectados por Testes Rápidos, com data ...         NaN
# 21          2                                                NaN         NaN
# 22          6  NOTA: O incremento de 48 óbitos em relação ao ...          16
# 23          9  horas e 32 óbitos em investigação que tiveram ...         NaN
# 24          2                                                NaN         NaN
# 25          2                                                NaN         NaN
# 26          8    NÚMERO DE SEPULTAMENTOS EM MANAUS EM 09/06/2020         NaN
# 27          6              Número TOTAL de sepultamentos por dia         NaN
# 28          1       Número TOTAL de óbitos domicliliares por dia         NaN
# 29          4                  Número TOTAL de cremações por dia         NaN
# 30          1                                                NaN         NaN
# 31          3                  Boletim Epidemiológico - SESAI/MS         NaN
# 32          5  Doença por Coronavírus (COVID-19) em populaçõe...         NaN
# 33          5  DSEI Suspeitos Confirmados Descartados Infecta...         NaN
# 34          7                            Alto Rio Negro 0 157 37         141
# 35          0                        Alto Rio Solimões 8 448 178          79
# 36        NaN                                  Manaus 10 166 106          78
# 37          0                             Médio Rio Purus 0 11 1           0
# 38        NaN                         Médio Rio Solimões 0 84 45          44
# 39          1                                   Parintins 0 30 2           9
# 40        NaN                            Vale do Javari 15 16 12          13
# 41        NaN                                   TOTAL 33 912 381         364
#
#                CONSOLIDADO CASOS DE
# 0                               NaN
# 1                               NaN
# 2                     LEITO CLÍNICO
# 3                               NaN
# 4                               469
# 5                            EM UTI
# 6                               NaN
# 7                               257
# 8                        INTERNADOS
# 9                               NaN
# 10                              726
# 11                              NaN
# 12                              NaN
# 13                   SRAG SUSPEITOS
# 14                  Em Investigação
# 15                            TOTAL
# 16                   Epidemiológica
# 17                          272 346
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22  óbitos ocorridos nas últimas 24
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                              NaN
# 27                               40
# 28                                6
# 29                                0
# 30                              NaN
# 31                              NaN
# 32                              NaN
# 33              Cura Clínica Óbitos
# 34                             11 5
# 35                           345 23
# 36                             80 4
# 37                             11 0
# 38                             34 6
# 39                             19 2
# 40                              3 0
# 41                           503 40

# %%
#Lendo somente a planilha de casos contidas no pdf 
df2 = tabula.read_pdf('boletim-diario-de-casos-covid-19-10-06-2020.pdf', area=[100,15,1500,1000], pages ='1'
)
df2[0]
# Out:
#       REDE  INTERNADOS  LEITO CLÍNICO       %  EM UTI     %.1
# 0  PRIVADA          84             31  36,90%      53  63,10%
# 1  PÚBLICA         276            182  65,94%      94  34,06%
# 2    TOTAL         360            213  59,17%     147  40,83%

# %%
df = df[0].drop('Unnamed: 0', axis = 1)
df
# Out:
#                      INTERNADOS CONFIRMADOS EM MANAUS  Unnamed: 1  \
# 0    INTERNAÇÃOREDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 1                                                 NaN         NaN
# 2                             PRIVADA 84 31 36,90% 53      63,10%
# 3                           PÚBLICA 276 182 65,94% 94      34,06%
# 4                            TOTAL 360 213 59,17% 147      40,83%
# 5                                                 NaN         NaN
# 6                      INTERNADOS SUSPEITOS EM MANAUS         NaN
# 7              REDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 8                             PRIVADA 66 42 63,64% 24      36,36%
# 9                           PÚBLICA 300 214 71,33% 86      28,67%
# 10                           TOTAL 366 256 69,95% 110      30,05%
# 11                                                NaN         NaN
# 12                                             ÓBITOS         NaN
# 13                                        Confirmados         NaN
# 14        Notificados Últimas Confirmação Descartados  Aguardando
# 15                                    Acumulado TOTAL         NaN
# 16                           24 horas Diagnóstica (5)   Resultado
# 17                     2.920 2.363 4,47% 16 32 48 211          74
# 18                                                NaN         NaN
# 19  NOTA: Do total de 1615 casos cofirmados nas úl...         NaN
# 20  foram detectados por Testes Rápidos, com data ...         NaN
# 21                                                NaN         NaN
# 22  NOTA: O incremento de 48 óbitos em relação ao ...          16
# 23  horas e 32 óbitos em investigação que tiveram ...         NaN
# 24                                                NaN         NaN
# 25                                                NaN         NaN
# 26    NÚMERO DE SEPULTAMENTOS EM MANAUS EM 09/06/2020         NaN
# 27              Número TOTAL de sepultamentos por dia         NaN
# 28       Número TOTAL de óbitos domicliliares por dia         NaN
# 29                  Número TOTAL de cremações por dia         NaN
# 30                                                NaN         NaN
# 31                  Boletim Epidemiológico - SESAI/MS         NaN
# 32  Doença por Coronavírus (COVID-19) em populaçõe...         NaN
# 33  DSEI Suspeitos Confirmados Descartados Infecta...         NaN
# 34                            Alto Rio Negro 0 157 37         141
# 35                        Alto Rio Solimões 8 448 178          79
# 36                                  Manaus 10 166 106          78
# 37                             Médio Rio Purus 0 11 1           0
# 38                         Médio Rio Solimões 0 84 45          44
# 39                                   Parintins 0 30 2           9
# 40                            Vale do Javari 15 16 12          13
# 41                                   TOTAL 33 912 381         364
#
#                CONSOLIDADO CASOS DE
# 0                               NaN
# 1                               NaN
# 2                     LEITO CLÍNICO
# 3                               NaN
# 4                               469
# 5                            EM UTI
# 6                               NaN
# 7                               257
# 8                        INTERNADOS
# 9                               NaN
# 10                              726
# 11                              NaN
# 12                              NaN
# 13                   SRAG SUSPEITOS
# 14                  Em Investigação
# 15                            TOTAL
# 16                   Epidemiológica
# 17                          272 346
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22  óbitos ocorridos nas últimas 24
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                              NaN
# 27                               40
# 28                                6
# 29                                0
# 30                              NaN
# 31                              NaN
# 32                              NaN
# 33              Cura Clínica Óbitos
# 34                             11 5
# 35                           345 23
# 36                             80 4
# 37                             11 0
# 38                             34 6
# 39                             19 2
# 40                              3 0
# 41                           503 40

# %%
df = df.drop([18,19,20,21])
df
# Out:
#                      INTERNADOS CONFIRMADOS EM MANAUS  Unnamed: 1  \
# 0    INTERNAÇÃOREDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 1                                                 NaN         NaN
# 2                             PRIVADA 84 31 36,90% 53      63,10%
# 3                           PÚBLICA 276 182 65,94% 94      34,06%
# 4                            TOTAL 360 213 59,17% 147      40,83%
# 5                                                 NaN         NaN
# 6                      INTERNADOS SUSPEITOS EM MANAUS         NaN
# 7              REDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 8                             PRIVADA 66 42 63,64% 24      36,36%
# 9                           PÚBLICA 300 214 71,33% 86      28,67%
# 10                           TOTAL 366 256 69,95% 110      30,05%
# 11                                                NaN         NaN
# 12                                             ÓBITOS         NaN
# 13                                        Confirmados         NaN
# 14        Notificados Últimas Confirmação Descartados  Aguardando
# 15                                    Acumulado TOTAL         NaN
# 16                           24 horas Diagnóstica (5)   Resultado
# 17                     2.920 2.363 4,47% 16 32 48 211          74
# 22  NOTA: O incremento de 48 óbitos em relação ao ...          16
# 23  horas e 32 óbitos em investigação que tiveram ...         NaN
# 24                                                NaN         NaN
# 25                                                NaN         NaN
# 26    NÚMERO DE SEPULTAMENTOS EM MANAUS EM 09/06/2020         NaN
# 27              Número TOTAL de sepultamentos por dia         NaN
# 28       Número TOTAL de óbitos domicliliares por dia         NaN
# 29                  Número TOTAL de cremações por dia         NaN
# 30                                                NaN         NaN
# 31                  Boletim Epidemiológico - SESAI/MS         NaN
# 32  Doença por Coronavírus (COVID-19) em populaçõe...         NaN
# 33  DSEI Suspeitos Confirmados Descartados Infecta...         NaN
# 34                            Alto Rio Negro 0 157 37         141
# 35                        Alto Rio Solimões 8 448 178          79
# 36                                  Manaus 10 166 106          78
# 37                             Médio Rio Purus 0 11 1           0
# 38                         Médio Rio Solimões 0 84 45          44
# 39                                   Parintins 0 30 2           9
# 40                            Vale do Javari 15 16 12          13
# 41                                   TOTAL 33 912 381         364
#
#                CONSOLIDADO CASOS DE
# 0                               NaN
# 1                               NaN
# 2                     LEITO CLÍNICO
# 3                               NaN
# 4                               469
# 5                            EM UTI
# 6                               NaN
# 7                               257
# 8                        INTERNADOS
# 9                               NaN
# 10                              726
# 11                              NaN
# 12                              NaN
# 13                   SRAG SUSPEITOS
# 14                  Em Investigação
# 15                            TOTAL
# 16                   Epidemiológica
# 17                          272 346
# 22  óbitos ocorridos nas últimas 24
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                              NaN
# 27                               40
# 28                                6
# 29                                0
# 30                              NaN
# 31                              NaN
# 32                              NaN
# 33              Cura Clínica Óbitos
# 34                             11 5
# 35                           345 23
# 36                             80 4
# 37                             11 0
# 38                             34 6
# 39                             19 2
# 40                              3 0
# 41                           503 40

# %%
df = df.drop([23,24,25,30])

# %%
df
# Out:
#                      INTERNADOS CONFIRMADOS EM MANAUS  Unnamed: 1  \
# 0    INTERNAÇÃOREDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 1                                                 NaN         NaN
# 2                             PRIVADA 84 31 36,90% 53      63,10%
# 3                           PÚBLICA 276 182 65,94% 94      34,06%
# 4                            TOTAL 360 213 59,17% 147      40,83%
# 5                                                 NaN         NaN
# 6                      INTERNADOS SUSPEITOS EM MANAUS         NaN
# 7              REDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 8                             PRIVADA 66 42 63,64% 24      36,36%
# 9                           PÚBLICA 300 214 71,33% 86      28,67%
# 10                           TOTAL 366 256 69,95% 110      30,05%
# 11                                                NaN         NaN
# 12                                             ÓBITOS         NaN
# 13                                        Confirmados         NaN
# 14        Notificados Últimas Confirmação Descartados  Aguardando
# 15                                    Acumulado TOTAL         NaN
# 16                           24 horas Diagnóstica (5)   Resultado
# 17                     2.920 2.363 4,47% 16 32 48 211          74
# 22  NOTA: O incremento de 48 óbitos em relação ao ...          16
# 26    NÚMERO DE SEPULTAMENTOS EM MANAUS EM 09/06/2020         NaN
# 27              Número TOTAL de sepultamentos por dia         NaN
# 28       Número TOTAL de óbitos domicliliares por dia         NaN
# 29                  Número TOTAL de cremações por dia         NaN
# 31                  Boletim Epidemiológico - SESAI/MS         NaN
# 32  Doença por Coronavírus (COVID-19) em populaçõe...         NaN
# 33  DSEI Suspeitos Confirmados Descartados Infecta...         NaN
# 34                            Alto Rio Negro 0 157 37         141
# 35                        Alto Rio Solimões 8 448 178          79
# 36                                  Manaus 10 166 106          78
# 37                             Médio Rio Purus 0 11 1           0
# 38                         Médio Rio Solimões 0 84 45          44
# 39                                   Parintins 0 30 2           9
# 40                            Vale do Javari 15 16 12          13
# 41                                   TOTAL 33 912 381         364
#
#                CONSOLIDADO CASOS DE
# 0                               NaN
# 1                               NaN
# 2                     LEITO CLÍNICO
# 3                               NaN
# 4                               469
# 5                            EM UTI
# 6                               NaN
# 7                               257
# 8                        INTERNADOS
# 9                               NaN
# 10                              726
# 11                              NaN
# 12                              NaN
# 13                   SRAG SUSPEITOS
# 14                  Em Investigação
# 15                            TOTAL
# 16                   Epidemiológica
# 17                          272 346
# 22  óbitos ocorridos nas últimas 24
# 26                              NaN
# 27                               40
# 28                                6
# 29                                0
# 31                              NaN
# 32                              NaN
# 33              Cura Clínica Óbitos
# 34                             11 5
# 35                           345 23
# 36                             80 4
# 37                             11 0
# 38                             34 6
# 39                             19 2
# 40                              3 0
# 41                           503 40

# %%
df = df.drop([1])
df
# Out:
#                      INTERNADOS CONFIRMADOS EM MANAUS  Unnamed: 1  \
# 0    INTERNAÇÃOREDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 2                             PRIVADA 84 31 36,90% 53      63,10%
# 3                           PÚBLICA 276 182 65,94% 94      34,06%
# 4                            TOTAL 360 213 59,17% 147      40,83%
# 5                                                 NaN         NaN
# 6                      INTERNADOS SUSPEITOS EM MANAUS         NaN
# 7              REDE INTERNADOS LEITO CLÍNICO % EM UTI           %
# 8                             PRIVADA 66 42 63,64% 24      36,36%
# 9                           PÚBLICA 300 214 71,33% 86      28,67%
# 10                           TOTAL 366 256 69,95% 110      30,05%
# 11                                                NaN         NaN
# 12                                             ÓBITOS         NaN
# 13                                        Confirmados         NaN
# 14        Notificados Últimas Confirmação Descartados  Aguardando
# 15                                    Acumulado TOTAL         NaN
# 16                           24 horas Diagnóstica (5)   Resultado
# 17                     2.920 2.363 4,47% 16 32 48 211          74
# 22  NOTA: O incremento de 48 óbitos em relação ao ...          16
# 26    NÚMERO DE SEPULTAMENTOS EM MANAUS EM 09/06/2020         NaN
# 27              Número TOTAL de sepultamentos por dia         NaN
# 28       Número TOTAL de óbitos domicliliares por dia         NaN
# 29                  Número TOTAL de cremações por dia         NaN
# 31                  Boletim Epidemiológico - SESAI/MS         NaN
# 32  Doença por Coronavírus (COVID-19) em populaçõe...         NaN
# 33  DSEI Suspeitos Confirmados Descartados Infecta...         NaN
# 34                            Alto Rio Negro 0 157 37         141
# 35                        Alto Rio Solimões 8 448 178          79
# 36                                  Manaus 10 166 106          78
# 37                             Médio Rio Purus 0 11 1           0
# 38                         Médio Rio Solimões 0 84 45          44
# 39                                   Parintins 0 30 2           9
# 40                            Vale do Javari 15 16 12          13
# 41                                   TOTAL 33 912 381         364
#
#                CONSOLIDADO CASOS DE
# 0                               NaN
# 2                     LEITO CLÍNICO
# 3                               NaN
# 4                               469
# 5                            EM UTI
# 6                               NaN
# 7                               257
# 8                        INTERNADOS
# 9                               NaN
# 10                              726
# 11                              NaN
# 12                              NaN
# 13                   SRAG SUSPEITOS
# 14                  Em Investigação
# 15                            TOTAL
# 16                   Epidemiológica
# 17                          272 346
# 22  óbitos ocorridos nas últimas 24
# 26                              NaN
# 27                               40
# 28                                6
# 29                                0
# 31                              NaN
# 32                              NaN
# 33              Cura Clínica Óbitos
# 34                             11 5
# 35                           345 23
# 36                             80 4
# 37                             11 0
# 38                             34 6
# 39                             19 2
# 40                              3 0
# 41                           503 40
